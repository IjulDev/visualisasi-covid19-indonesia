# %%
# !pip install descartes
# !pip install geopandas
# !pip install matplotlib
# !pip install numpy
# !pip install pandas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
geometryFile = './IDN_adm1.shp'
map_df = gpd.read_file(geometryFile)
display(map_df)
# plt.rcParams['figure.figsize'] = [50, 70]
# map_df.plot()
# Out:
#     ID_0  ISO     NAME_0  ID_1               NAME_1                 TYPE_1  \
# 0    106  IDN  Indonesia     1                 Aceh               Propinsi
# 1    106  IDN  Indonesia     2                 Bali               Propinsi
# 2    106  IDN  Indonesia     3      Bangka-Belitung               Propinsi
# 3    106  IDN  Indonesia     4               Banten               Propinsi
# 4    106  IDN  Indonesia     5             Bengkulu               Propinsi
# 5    106  IDN  Indonesia     6            Gorontalo               Propinsi
# 6    106  IDN  Indonesia     7     Irian Jaya Barat               Propinsi
# 7    106  IDN  Indonesia     8         Jakarta Raya  Daerah Khusus Ibukota
# 8    106  IDN  Indonesia     9                Jambi               Propinsi
# 9    106  IDN  Indonesia    10           Jawa Barat               Propinsi
# 10   106  IDN  Indonesia    11          Jawa Tengah                   City
# 11   106  IDN  Indonesia    12           Jawa Timur               Propinsi
# 12   106  IDN  Indonesia    13     Kalimantan Barat               Propinsi
# 13   106  IDN  Indonesia    14   Kalimantan Selatan               Propinsi
# 14   106  IDN  Indonesia    15    Kalimantan Tengah               Propinsi
# 15   106  IDN  Indonesia    16     Kalimantan Timur               Propinsi
# 16   106  IDN  Indonesia    17     Kalimantan Utara               Propinsi
# 17   106  IDN  Indonesia    18       Kepulauan Riau               Propinsi
# 18   106  IDN  Indonesia    19              Lampung               Propinsi
# 19   106  IDN  Indonesia    20         Maluku Utara               Propinsi
# 20   106  IDN  Indonesia    21               Maluku               Propinsi
# 21   106  IDN  Indonesia    22  Nusa Tenggara Barat               Propinsi
# 22   106  IDN  Indonesia    23  Nusa Tenggara Timur               Propinsi
# 23   106  IDN  Indonesia    24                Papua               Propinsi
# 24   106  IDN  Indonesia    25                 Riau               Propinsi
# 25   106  IDN  Indonesia    26       Sulawesi Barat               Propinsi
# 26   106  IDN  Indonesia    27     Sulawesi Selatan               Propinsi
# 27   106  IDN  Indonesia    28      Sulawesi Tengah               Propinsi
# 28   106  IDN  Indonesia    29    Sulawesi Tenggara               Propinsi
# 29   106  IDN  Indonesia    30       Sulawesi Utara               Propinsi
# 30   106  IDN  Indonesia    31       Sumatera Barat               Propinsi
# 31   106  IDN  Indonesia    32     Sumatera Selatan               Propinsi
# 32   106  IDN  Indonesia    33       Sumatera Utara               Propinsi
# 33   106  IDN  Indonesia    34           Yogyakarta        Daerah Istimewa
#
#               ENGTYPE_1 NL_NAME_1  \
# 0   Autonomous Province      None
# 1              Province      None
# 2              Province      None
# 3              Province      None
# 4              Province      None
# 5              Province      None
# 6              Province      None
# 7      Special district      None
# 8              Province      None
# 9              Province      None
# 10                 City      None
# 11             Province      None
# 12             Province      None
# 13             Province      None
# 14             Province      None
# 15             Province      None
# 16             Province      None
# 17             Province      None
# 18             Province      None
# 19             Province      None
# 20             Province      None
# 21             Province      None
# 22             Province      None
# 23             Province      None
# 24             Province      None
# 25             Province      None
# 26             Province      None
# 27             Province      None
# 28             Province      None
# 29             Province      None
# 30             Province      None
# 31             Province      None
# 32             Province      None
# 33       Special region      None
#
#                                             VARNAME_1  \
# 0                Achin|Atjeh|Nanggroe Aceh Darussalam
# 1                 Penida|Lembongan|Ceningan|Menjangan
# 2                     Babel|Kepulauan Bangka Belitung
# 3                                                None
# 4                        Bencoolen|Benkoelen|Benkulen
# 5                                                None
# 6   New Guinea|Yos Sudarso or Frederick Hendrik|Wa...
# 7                                       Jawa|Djakarta
# 8                                              Djambi
# 9                                               Jabar
# 10                                             Jateng
# 11                                              Jatim
# 12                            West Kalimantan| Kalbar
# 13                                             Kalsel
# 14                                            Kalteng
# 15                                             Kaltim
# 16                                             Kaltim
# 17                                               None
# 18                                               None
# 19                                              Malut
# 20       Molucas||Moluccas|Molucche|Moluckerna|Moluqu
# 21                                                NTB
# 22                                                NTT
# 23  New Guinea|Yos Sudarso or Frederick Hendrik|Wa...
# 24                                    Rhio|Riou|Riouw
# 25                                             Sulsel
# 26                                             Sulsel
# 27                                            Sulteng
# 28                                             Sultra
# 29                                              Sulut
# 30                                             Sumbar
# 31                                             Sumsel
# 32                                              Sumut
# 33                    Jawa|Daerah Istimewa Yogyakarta
#
#                                              geometry
# 0   MULTIPOLYGON (((97.38493 1.97713, 97.38396 1.9...
# 1   MULTIPOLYGON (((115.62988 -8.77599, 115.63037 ...
# 2   MULTIPOLYGON (((108.06951 -3.80305, 108.06826 ...
# 3   MULTIPOLYGON (((105.54861 -6.99472, 105.54889 ...
# 4   MULTIPOLYGON (((102.38627 -5.47112, 102.38682 ...
# 5   MULTIPOLYGON (((122.12139 0.40583, 122.12167 0...
# 6   MULTIPOLYGON (((133.50668 -4.32504, 133.50676 ...
# 7   MULTIPOLYGON (((106.73338 -6.09776, 106.73373 ...
# 8   MULTIPOLYGON (((104.21628 -1.06326, 104.21578 ...
# 9   MULTIPOLYGON (((107.85297 -7.73661, 107.85330 ...
# 10  MULTIPOLYGON (((109.01002 -7.68037, 109.01002 ...
# 11  MULTIPOLYGON (((114.02917 -8.64806, 114.02917 ...
# 12  MULTIPOLYGON (((110.20528 -3.06639, 110.20528 ...
# 13  MULTIPOLYGON (((117.05028 -5.08833, 117.05055 ...
# 14  MULTIPOLYGON (((113.36195 -3.28445, 113.36195 ...
# 15  MULTIPOLYGON (((117.94273 -2.53682, 117.94328 ...
# 16  MULTIPOLYGON (((117.61222 2.81333, 117.61222 2...
# 17  MULTIPOLYGON (((104.41074 -0.86626, 104.40942 ...
# 18  MULTIPOLYGON (((105.44666 -6.13285, 105.44806 ...
# 19  MULTIPOLYGON (((124.37479 -2.00665, 124.39085 ...
# 20  MULTIPOLYGON (((126.08830 -9.03179, 126.08788 ...
# 21  MULTIPOLYGON (((117.19965 -9.01612, 117.20077 ...
# 22  MULTIPOLYGON (((122.86732 -10.96568, 122.86783...
# 23  MULTIPOLYGON (((138.92583 -8.32361, 138.92639 ...
# 24  MULTIPOLYGON (((103.64757 -0.23855, 103.64757 ...
# 25  MULTIPOLYGON (((119.35892 -3.48698, 119.35906 ...
# 26  MULTIPOLYGON (((121.80334 -7.49083, 121.80222 ...
# 27  MULTIPOLYGON (((123.15244 -3.55653, 123.15298 ...
# 28  MULTIPOLYGON (((122.68833 -6.17778, 122.68945 ...
# 29  MULTIPOLYGON (((124.35252 0.41743, 124.35217 0...
# 30  MULTIPOLYGON (((101.05139 -3.99194, 101.05361 ...
# 31  MULTIPOLYGON (((106.21500 -3.21528, 106.21528 ...
# 32  MULTIPOLYGON (((98.50278 -0.59528, 98.50305 -0...
# 33  MULTIPOLYGON (((110.07694 -7.91583, 110.07750 ...

# %%
covid_df = pd.read_csv('./covid_19_indonesia_time_series_all.csv')
display(covid_df)
# Out:
#          Date Location ISO Code                    Location  New Cases  \
# 0   9/15/2022             ID-AC                        Aceh         20
# 1   9/15/2022             ID-BA                        Bali         38
# 2   9/15/2022             ID-BT                      Banten        240
# 3   9/15/2022             ID-BE                    Bengkulu          4
# 4   9/15/2022             ID-YO  Daerah Istimewa Yogyakarta         27
# 5   9/15/2022             ID-JK                 DKI Jakarta       1116
# 6   9/14/2022             ID-GO                   Gorontalo          1
# 7   9/15/2022             ID-JA                       Jambi          8
# 8   9/15/2022             ID-JB                  Jawa Barat        492
# 9   9/15/2022             ID-JT                 Jawa Tengah        108
# 10  9/15/2022             ID-JI                  Jawa Timur        268
# 11  9/15/2022             ID-KB            Kalimantan Barat         17
# 12  9/15/2022             ID-KS          Kalimantan Selatan         20
# 13  9/15/2022             ID-KT           Kalimantan Tengah         13
# 14  9/15/2022             ID-KI            Kalimantan Timur         26
# 15  9/15/2022             ID-KU            Kalimantan Utara          1
# 16  9/15/2022             ID-BB   Kepulauan Bangka Belitung         10
# 17  9/15/2022             ID-KR              Kepulauan Riau          8
# 18  9/15/2022             ID-LA                     Lampung         21
# 19  9/15/2022             ID-MA                      Maluku          9
# 20  9/15/2022             ID-MU                Maluku Utara          2
# 21  9/15/2022             ID-NB         Nusa Tenggara Barat          2
# 22  9/15/2022             ID-NT         Nusa Tenggara Timur         11
# 23  9/15/2022             ID-PA                       Papua         16
# 24  9/15/2022             ID-PB                 Papua Barat          7
# 25  9/15/2022             ID-RI                        Riau         19
# 26  9/14/2022             ID-SR              Sulawesi Barat          1
# 27  9/15/2022             ID-SN            Sulawesi Selatan          9
# 28  9/15/2022             ID-ST             Sulawesi Tengah         12
# 29  9/15/2022             ID-SG           Sulawesi Tenggara          2
# 30  9/15/2022             ID-SA              Sulawesi Utara         37
# 31  9/15/2022             ID-SB              Sumatera Barat         13
# 32  9/15/2022             ID-SS            Sumatera Selatan         16
# 33  9/15/2022             ID-SU              Sumatera Utara         50
#
#     New Deaths  New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0            0              1                19        44038          2223
# 1            1              6                31       166831          4731
# 2            0             32               208       333875          2950
# 3            0              0                 4        29173           522
# 4            0              0                27       224307          5928
# 5            0             58              1058      1412511         15513
# 6            0              0                 1        13951           487
# 7            0              0                 8        38643           889
# 8            0             79               413      1173731         15937
# 9            0              2               106       636409         33489
# 10           0             43               225       601545         31764
# 11           0              0                17        65605          1132
# 12           0              0                20        87476          2583
# 13           0              1                12        58217          1565
# 14           0              9                17       209017          5726
# 15           0              0                 1        45417           860
# 16           0              0                10        66144          1616
# 17           0              0                 8        70883          1888
# 18           0              1                20        75485          4186
# 19           0              0                 9        18736           295
# 20           0              0                 2        14595           334
# 21           0              0                 2        36247           902
# 22           0              0                11        94415          1527
# 23           0              0                16        49927           580
# 24           0              0                 7        32170           385
# 25           0              1                18       152648          4452
# 26           0              0                 1        15601           394
# 27           0              2                 7       144494          2485
# 28           0              0                12        61099          1733
# 29           0              0                 2        25693           569
# 30           0              0                37        52770          1213
# 31           0              3                10       104640          2371
# 32           0              1                15        82198          3376
# 33           0              5                45       158866          3288
#
#     Total Recovered  ...  Latitude New Cases per Million  \
# 14                 161.20              2.74%              97.13%
# 15                 132.63              1.89%              98.05%
# 16                 117.12              2.44%              97.45%
# 17                  97.85              2.66%              97.15%
# 18                  46.02              5.55%              94.16%
# 19                  15.97              1.57%              98.17%
# 20                  25.54              2.29%              97.62%
# 21                  17.11              2.49%              97.47%
# 22                  28.22              1.62%              98.27%
# 23                  13.36              1.16%              98.37%
# 24                  33.75              1.20%              98.38%
# 25                  73.29              2.92%              96.94%
# 26                  25.26              2.53%              97.44%
# 27                  26.36              1.72%              98.18%
# 28                  58.64              2.84%              97.02%
# 29                  21.59              2.21%              97.65%
# 30                  45.91              2.30%              96.64%
# 31                  42.96              2.27%              97.54%
# 32                  41.08              4.11%              95.51%
# 33                  22.10              2.07%              97.52%
#
#    Growth Factor of New Cases  Growth Factor of New Deaths
# 0                        2.50                          1.0
# 1                        6.33                          NaN
# 2                        1.83                          1.0
# 3                        0.50                          1.0
# 4                        2.25                          1.0
# 5                        0.91                          0.0
# 6                         NaN                          1.0
# 7                        8.00                          1.0
# 8                        2.58                          1.0
# 9                        0.88                          0.0
# 10                       5.06                          0.0
# 11                       8.50                          1.0
# 12                        NaN                          1.0
# 13                       0.93                          1.0
# 14                       2.89                          1.0
# 15                       1.00                          1.0
# 16                       5.00                          1.0
# 17                       1.14                          1.0
# 18                      10.50                          1.0
# 19                       9.00                          1.0
# 20                       2.00                          1.0
# 21                        NaN                          1.0
# 22                       3.67                          1.0
# 23                       4.00                          1.0
# 24                       1.17                          1.0
# 25                       1.19                          1.0
# 26                        NaN                          1.0
# 27                       0.50                          1.0
# 28                       2.40                          1.0
# 29                        NaN                          1.0
# 30                       2.85                          1.0
# 31                       6.50                          1.0
# 32                       3.20                          1.0
# 33                       1.92                          1.0
#
# [34 rows x 38 columns]

# %%
df_join = map_df.merge(covid_df, how='inner', left_on='NAME_1', right_on='Province')
df_join = df_join[['Province', 'geometry', 'Total Cases']]
df_join.head()
# Out:
#           Province                                           geometry  \
# 0             Aceh  MULTIPOLYGON (((97.38493 1.97713, 97.38396 1.9...
# 1             Bali  MULTIPOLYGON (((115.62988 -8.77599, 115.63037 ...
# 2  Bangka-Belitung  MULTIPOLYGON (((108.06951 -3.80305, 108.06826 ...
# 3           Banten  MULTIPOLYGON (((105.54861 -6.99472, 105.54889 ...
# 4         Bengkulu  MULTIPOLYGON (((102.38627 -5.47112, 102.38682 ...
#
#    Total Cases
# 0        44038
# 1       166831
# 2        66144
# 3       333875
# 4        29173

# %%
variable = 'Total Cases'
vmin, vmax = 0, 1412511
fig, ax = plt.subplots(1, figsize=(30,10))
ax.axis('off')
ax.set_title('Visualisasi Total Kasus Covid-19 Berdasarkan Provinsi', fontdict={'fontsize': '25', 'fontweight': '3'})
ax.annotate('By: Mhd. Zulfikar Pinem', xy=(0.6, .05), xycoords='figure fraction', fontsize=12, color='#555555')
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm.set_array([])
fig.colorbar(sm)
df_join.plot(column=variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8')
df_join['coords'] = df_join['geometry'].apply(lambda x: x.representative_point().coords[:])
df_join['coords'] = [coords[0] for coords in df_join['coords']]
for idx, row in df_join.iterrows():
  plt.annotate(s=row['Province'], xy=row['coords'], horizontalalignment='center')

# %%
fig.savefig('map.png', dpi=300)
